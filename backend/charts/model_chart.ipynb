# %%
import matplotlib.pyplot as plt


def plot_pie_chart(labels, sizes):

    colors = ['royalblue', 'seagreen', 'darkorange', 'firebrick', 'darkorchid'] 

    # Plotting the pie chart without labels
    plt.pie(sizes, colors=colors[:len(labels)], autopct='%1.1f%%', shadow=False, startangle=90, counterclock=False)

    # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.axis('equal')

    # Adding a legend at the bottom
    #plt.legend(labels, loc="lower center", bbox_to_anchor=(0.5, -0.1), ncol=len(labels))
    plt.legend(labels, loc="lower center", bbox_to_anchor=(0.5, -0.2), ncol=3)
    
    # Title of the chart
    # plt.title('Pie Chart with Labels at the Bottom')

    # Display the chart
    plt.show()

# %% [markdown]
# # Model Satisfaction

# %% [markdown]
# Model 1	8 \
# Model 2	4 \
# Model 3	2 \
# Model 4	6 \
# Model 5	5

# %%
labels = ["text-embedding-004 (Google)", "voyage-large-2 (VoyageAI)", "text-embedding-3-large (OpenAI)", "mistral-embed (MistralAI)", "embed-english-v3.0 (Cohere)"]
sizes = [8,4,2,6,5]  

plot_pie_chart(labels=labels, sizes=sizes)
